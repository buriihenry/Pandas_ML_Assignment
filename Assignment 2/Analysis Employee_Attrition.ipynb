# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("HR_Employee_Attrition.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.Attrition.value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.BusinessTravel.value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %% [markdown]
# 1. Show a breakdown of distance from home by job role and attrition.

# %%
df1 = df[['Attrition','DistanceFromHome','Education','JobRole','MonthlyIncome']]
df1
# Out:
#      Attrition  DistanceFromHome  Education                    JobRole  \
# 0          Yes                 1          2            Sales Executive
# 1           No                 8          1         Research Scientist
# 2          Yes                 2          2      Laboratory Technician
# 3           No                 3          4         Research Scientist
# 4           No                 2          1      Laboratory Technician
# ...        ...               ...        ...                        ...
# 1465        No                23          2      Laboratory Technician
# 1466        No                 6          1  Healthcare Representative
# 1467        No                 4          3     Manufacturing Director
# 1468        No                 2          3            Sales Executive
# 1469        No                 8          3      Laboratory Technician
#
#       MonthlyIncome
# 0              5993
# 1              5130
# 2              2090
# 3              2909
# ...

# %%
df2 = df1[['DistanceFromHome','JobRole','Attrition']][df1['Attrition']=='Yes']
df3 = df1[['DistanceFromHome','JobRole','Attrition']][df1['Attrition']=='No']

# %%
df2=df2.rename(columns={'Attrition':'Attrition_Yes'})
df3=df3.rename(columns={'Attrition':'Attrition_No'})

# %%
df2
# Out:
#       DistanceFromHome                JobRole Attrition_Yes
# 0                    1        Sales Executive           Yes
# 2                    2  Laboratory Technician           Yes
# 14                  24  Laboratory Technician           Yes
# 21                   9   Sales Representative           Yes
# 24                   6     Research Scientist           Yes
# ...                ...                    ...           ...
# 1438                 9   Sales Representative           Yes
# 1442                 1     Research Scientist           Yes
# 1444                 7  Laboratory Technician           Yes
# 1452                 1        Sales Executive           Yes
# 1461                28        Sales Executive           Yes
#
# [237 rows x 3 columns]

# %%
df3
# Out:
#       DistanceFromHome                    JobRole Attrition_No
# 1                    8         Research Scientist           No
# 3                    3         Research Scientist           No
# 4                    2      Laboratory Technician           No
# 5                    2      Laboratory Technician           No
# 6                    3      Laboratory Technician           No
# ...                ...                        ...          ...
# 1465                23      Laboratory Technician           No
# 1466                 6  Healthcare Representative           No
# 1467                 4     Manufacturing Director           No
# 1468                 2            Sales Executive           No
# 1469                 8      Laboratory Technician           No
#
# [1233 rows x 3 columns]

# %%
#check columns in the DataFrame
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df2.groupby(['DistanceFromHome','JobRole']).count()
# Out:
#                                             Attrition_Yes
# DistanceFromHome JobRole
# 1                Human Resources                        1
#                  Laboratory Technician                  4
#                  Manufacturing Director                 1
#                  Research Scientist                     7
#                  Sales Executive                        6
# ...                                                   ...
# 29               Healthcare Representative              1
#                  Laboratory Technician                  1
#                  Manager                                1
#                  Research Scientist                     1
#                  Sales Executive                        1
#
# [112 rows x 1 columns]

# %%
df3.groupby(['DistanceFromHome','JobRole']).count()
# Out:
#                                             Attrition_No
# DistanceFromHome JobRole
# 1                Healthcare Representative            23
#                  Human Resources                       8
#                  Laboratory Technician                27
#                  Manager                              13
#                  Manufacturing Director               23
# ...                                                  ...
# 29               Manager                               3
#                  Manufacturing Director                4
#                  Research Scientist                    3
#                  Sales Executive                       4
#                  Sales Representative                  1
#
# [217 rows x 1 columns]

# %%
Attrition_mapping = {"Yes": 1, "No": 0}
df['Attrition'] = df['Attrition'].map(Attrition_mapping)

# %%
#ploting attrition column
sns.countplot(df['Attrition'])

# %%
attrition = df[(df['Attrition'] != 0)]
no_attrition = df[(df['Attrition'] == 0)]
print('Percentage of Attrition: {}'.format(len(attrition)/len(df)))

# %%
df[['Gender', 'Attrition']].groupby(['Gender'], as_index=False).mean().sort_values(by='Attrition', ascending=False)

# %% [markdown]
# Males have higher attrition rate than women

# %%
df[['JobRole', 'Attrition']].groupby(['JobRole'], as_index=False).mean().sort_values(by='Attrition', ascending=False)

# %% [markdown]
# Sales Reps are highly likely to leave the job

# %%
df[['DistanceFromHome', 'JobRole', 'Attrition']].groupby(['DistanceFromHome','JobRole'], as_index=False).mean().sort_values(by='Attrition', ascending=False)

# %%
#check columns in the DataFrame
df.columns

# %% [markdown]
# Distance from home by job role & attrition

# %%
df[['MonthlyIncome', 'Education', 'Attrition']].groupby(['MonthlyIncome','Education'], as_index=False).mean().sort_values(by='Attrition', ascending=False)

# %%
sns.distplot(df['Education'])

# %%
plt.hist(df.Age)
